# %% [markdown]
# # Face Detection, Allignment, Embeddings, Clustering
#
# ### About
# - Here is a very nice review of the current (2020.08) state of Deep Learning in face recognition: "Deep Face Recognition: A Survey" https://arxiv.org/abs/1804.06655
# - In this notebook we use pretrained MTCNN (multi-task convolutional neural network) to detect faces on photos and find landmarks (eyes, nose, mouth) on faces.
# - Pretrained FaceNet NN is used to generate face embeddings (128 point vector encoding discriminative features of faces as learned by NN).
# - Both NN are based on FaceNet architecture - google development, which won prestigeous ImageNet competition in 2015 surpassing human performance in face recognition task.
#
# ### Environment, libraries
# - In order to get to the results a number of libraries have to be imported (please check the Environment folder for help on how to setup the environment).
# - Libraries and helper functions are in utils.py, which is run at the beginning of this notebook.
#
#
# ### Notebook content:
# - 0. Correct jpg files metadata
# - 1. MTCNN (detect faces on photos)
# - 2. Filter results (remove bad quality photos)
# - 3. FaceNet embeddings (obtain 128-dim vector/embedding representing faces features numerically with FaceNet)
# - 4. t-SNE: 2-D representation of clustering similar photos together and separating different photos further from each other.

# %%
# Load libraries and helper functions by running utils.py with a jupyter magic function:
# %run utils.py
# Out:
# Libraries and functions loaded

# %% [markdown]
# ## 0. Correct jpg files metadata (creation-time)
# It is often that metadata for jpg files is wrong (e.g. the camera was not set correctly), here are some usefull functions to check and correct the metadata:

# %% [markdown]
# ### Check metadata for jpg files

# %%
# Scan over immediate subfolders in the main directory folder and check creation times within these subfolders
directory = r'D:\Photo'
print_creation_times_for_subfolders(directory)
# Out:
# Number of immediate subfolders:  311
#
# 0
# D:\Photo\2012.12.26-05 Джермания
# 1557 jpg files in subdirectory
# years: 2012 - 2012 ; months: 12 - 12 ; days: 26 - 26
#
# 1
# D:\Photo\2008.06.28 Карма
# 2 jpg files in subdirectory
# years: 2008 - 2008 ; months: 6 - 6 ; days: 28 - 28
#
# 2
# D:\Photo\2008.07.20 Приключения итальянцев в России
# 41 jpg files in subdirectory
# years: 2008 - 2008 ; months: 7 - 7 ; days: 20 - 20
#
# 3
# D:\Photo\2008.08.02 Сергиев Посад
# 100 jpg files in subdirectory
# years: 2008 - 2008 ; months: 8 - 8 ; days: 2 - 2
#
# 4
# D:\Photo\2008.10 Осень
# 141 jpg files in subdirectory
# years: 2008 - 2008 ; months: 10 - 10 ; days: 15 - 15
#
# 5
# D:\Photo\2008.12 У Аллы
# 16 jpg files in subdirectory
# years: 2008 - 2008 ; months: 12 - 12 ; days: 2 - 2
#
# 6
# D:\Photo\2008.12.26 Танин корпоратив
# 12 jpg files in subdirectory
# years: 2008 - 2008 ; months: 12 - 12 ; days: 26 - 26
#
# 7
# D:\Photo\2008.12.28 ДР Таниной мамы
# 82 jpg files in subdirectory
# years: 2008 - 2008 ; months: 12 - 12 ; days: 28 - 28
#
# 8
# D:\Photo\2009 Юля фотографирует
# 105 jpg files in subdirectory
# years: 2009 - 2009 ; months: 11 - 11 ; days: 9 - 9
#
# 9
# D:\Photo\2009.01 Вилюня
# 83 jpg files in subdirectory
# years: 2009 - 2009 ; months: 1 - 1 ; days: 15 - 15
#
# 10
# D:\Photo\2009.02.14 Все праздники 2009
# 131 jpg files in subdirectory
# years: 2009 - 2009 ; months: 2 - 2 ; days: 14 - 14
#
# 11
# D:\Photo\2009.02.23 В гостях у Таниных+++
# 63 jpg files in subdirectory
# years: 2009 - 2009 ; months: 2 - 2 ; days: 23 - 23
#
# 12
# D:\Photo\2009.02.23 Лесин ДР
# 20 jpg files in subdirectory
# years: 2009 - 2009 ; months: 2 - 3 ; days: 1 - 28
#
# 13
# D:\Photo\2009.03.20 Катин ДР++++
# 127 jpg files in subdirectory
# years: 2009 - 2009 ; months: 3 - 3 ; days: 20 - 20
#
# 14
# D:\Photo\2009.03.22 Му-Мы
# 34 jpg files in subdirectory
# years: 2009 - 2009 ; months: 3 - 3 ; days: 22 - 22
#
# 15
# D:\Photo\2009.03.27 Гигантский слалом
# 8 jpg files in subdirectory
# years: 2009 - 2009 ; months: 3 - 3 ; days: 27 - 27
#
# 16
# D:\Photo\2009.04.10 Таня с хвостиком
# 10 jpg files in subdirectory
# years: 2009 - 2009 ; months: 4 - 4 ; days: 10 - 10
#
# 17
# D:\Photo\2009.04.17 В гостях у Таниных
# 19 jpg files in subdirectory
# years: 2009 - 2009 ; months: 4 - 4 ; days: 17 - 17
#
# 18
# D:\Photo\2009.04.26 Шашлык, зелен
# 26 jpg files in subdirectory
# years: 2009 - 2009 ; months: 4 - 4 ; days: 26 - 26
#
# 19
# D:\Photo\2009.05.01 Променад у Москва-сити
# 29 jpg files in subdirectory
# years: 2009 - 2009 ; months: 5 - 5 ; days: 1 - 1
#
# 20
# D:\Photo\2009.05.02 Чачлыкчки с Кэтрей+++
# 173 jpg files in subdirectory
# years: 2009 - 2009 ; months: 5 - 5 ; days: 2 - 2
#
# 21
# D:\Photo\2009.05.03 В Ботаническом аду
# 20 jpg files in subdirectory
# years: 2009 - 2009 ; months: 5 - 5 ; days: 3 - 3
#
# 22
# D:\Photo\2009.05.09 Дача
# 53 jpg files in subdirectory
# years: 2009 - 2009 ; months: 5 - 5 ; days: 6 - 10
#
# 23
# D:\Photo\2009.05.11 Коломенское
# 23 jpg files in subdirectory
# years: 2009 - 2009 ; months: 5 - 5 ; days: 11 - 11
#
# 24
# D:\Photo\2009.05.16 НА даче
# 139 jpg files in subdirectory
# years: 2009 - 2009 ; months: 5 - 5 ; days: 16 - 16
#
# 25
# D:\Photo\2009.05.31 Царицыно
# 76 jpg files in subdirectory
# years: 2009 - 2009 ; months: 5 - 5 ; days: 31 - 31
#
# 26
# D:\Photo\2009.06.06-07 Питер
# 204 jpg files in subdirectory
# years: 2009 - 2009 ; months: 6 - 6 ; days: 6 - 6
#
# 27
# D:\Photo\2009.06.11-28 Крым, лета
# 964 jpg files in subdirectory
# years: 2009 - 2009 ; months: 6 - 6 ; days: 11 - 11
#
# 28
# D:\Photo\2009.07.12 Водники
# 21 jpg files in subdirectory
# years: 2009 - 2009 ; months: 7 - 7 ; days: 12 - 12
#
# 29
# D:\Photo\2009.07.18 Поход на сальсу
# 16 jpg files in subdirectory
# years: 2009 - 2009 ; months: 7 - 7 ; days: 18 - 18
#
# 30
# D:\Photo\2009.08 Альбишка в Москве
# 573 jpg files in subdirectory
# years: 2009 - 2009 ; months: 8 - 8 ; days: 15 - 15
#
# 31
# D:\Photo\2009.08 Баловство
# 82 jpg files in subdirectory
# years: 2009 - 2009 ; months: 8 - 8 ; days: 16 - 16
#
# 32
# D:\Photo\2009.08.20 Фотосессия
# 96 jpg files in subdirectory
# years: 2009 - 2009 ; months: 8 - 8 ; days: 20 - 20
#
# 33
# D:\Photo\2009.08.23 Дача
# 34 jpg files in subdirectory
# years: 2009 - 2009 ; months: 8 - 8 ; days: 23 - 23
#
# 34
# D:\Photo\2009.09 Баня, дача
# 213 jpg files in subdirectory
# years: 2009 - 2009 ; months: 9 - 9 ; days: 29 - 29
#
# 35
# D:\Photo\2009.09 Юлин концерт
# 13 jpg files in subdirectory
# years: 2009 - 2009 ; months: 9 - 9 ; days: 15 - 15
#
# 36
# D:\Photo\2009.09.29 ДР Таниной бабушки
# 102 jpg files in subdirectory
# years: 2009 - 2009 ; months: 9 - 9 ; days: 29 - 29
#
# 37
# D:\Photo\2009.10.21 RFW
# 31 jpg files in subdirectory
# years: 2009 - 2009 ; months: 10 - 10 ; days: 21 - 21
#
# 38
# D:\Photo\2009.10.24 Оcень. Переводим часы назад
# 86 jpg files in subdirectory
# years: 2009 - 2009 ; months: 10 - 10 ; days: 24 - 24
#
# 39
# D:\Photo\2009.11.30 День рождения мамы
# 5 jpg files in subdirectory
# years: 2009 - 2009 ; months: 11 - 11 ; days: 30 - 30
#
# 40
# D:\Photo\2009.12.10 Женин корпоратив
# 235 jpg files in subdirectory
# years: 2009 - 2009 ; months: 12 - 12 ; days: 10 - 10
#
# 41
# D:\Photo\2010.01.01 Новогодняя ночь у Пыхычей
# 73 jpg files in subdirectory
# years: 2010 - 2010 ; months: 1 - 1 ; days: 1 - 1
#
# 42
# D:\Photo\2010.01.21 Новоселье, Новый дом
# 63 jpg files in subdirectory
# years: 2010 - 2010 ; months: 1 - 1 ; days: 21 - 21
#
# 43
# D:\Photo\2010.02 Хрустальная свадьба в Ростове
# 7 jpg files in subdirectory
# years: 2010 - 2010 ; months: 2 - 2 ; days: 21 - 21
#
# 44
# D:\Photo\2010.02.13 Родители в гостях
# 11 jpg files in subdirectory
# years: 2010 - 2010 ; months: 2 - 2 ; days: 13 - 13
#
# 45
# D:\Photo\2010.02.14 ДCВ на катке
# 13 jpg files in subdirectory
# years: 2010 - 2010 ; months: 2 - 2 ; days: 14 - 14
#
# 46
# D:\Photo\2010.02.27 ДР Шурика
# 9 jpg files in subdirectory
# years: 2010 - 2010 ; months: 2 - 2 ; days: 27 - 27
#
# 47
# D:\Photo\2010.03 Германия, Альпы, лыжи, красота
# 915 jpg files in subdirectory
# years: 2010 - 2010 ; months: 3 - 3 ; days: 20 - 20
#
# 48
# D:\Photo\2010.04 Домашние
# 134 jpg files in subdirectory
# years: 2010 - 2010 ; months: 4 - 4 ; days: 15 - 15
#
# 49
# D:\Photo\2010.04.03-17 Сингапур, Заюшкина учеба
# 377 jpg files in subdirectory
# years: 2010 - 2010 ; months: 4 - 4 ; days: 10 - 16
#
# 50
# D:\Photo\2010.04.04 RFW
# 39 jpg files in subdirectory
# years: 2010 - 2010 ; months: 4 - 4 ; days: 4 - 4
#
# 51
# D:\Photo\2010.04.10 Япошин день )
# 240 jpg files in subdirectory
# years: 2010 - 2010 ; months: 4 - 4 ; days: 10 - 10
#
# 52
# D:\Photo\2010.04.18 В гостях у Жениных
# 53 jpg files in subdirectory
# years: 2010 - 2010 ; months: 4 - 4 ; days: 18 - 18
#
# 53
# D:\Photo\2010.04.23 В гостях у Таниных
# 61 jpg files in subdirectory
# years: 2010 - 2010 ; months: 4 - 4 ; days: 19 - 24
#
# 54
# D:\Photo\2010.04.29 Екатерининский парк
# 60 jpg files in subdirectory
# years: 2010 - 2010 ; months: 4 - 4 ; days: 30 - 30
#
# 55
# D:\Photo\2010.04.30-03 Майские праздники_караоке+дача
# 199 jpg files in subdirectory
# years: 2010 - 2010 ; months: 4 - 4 ; days: 30 - 30
#
# 56
# D:\Photo\2010.05.08-09 Дача
# 280 jpg files in subdirectory
# years: 2010 - 2010 ; months: 5 - 5 ; days: 8 - 8
#
# 57
# D:\Photo\2010.05.12 Как Зайцы нам замуж предлагали =)
# 113 jpg files in subdirectory
# years: 2010 - 2010 ; months: 5 - 5 ; days: 13 - 13
#
# 58
# D:\Photo\2010.05.15 Прогулочка к МГУ
# 185 jpg files in subdirectory
# years: 2010 - 2010 ; months: 5 - 5 ; days: 15 - 15
#
# 59
# D:\Photo\2010.05.16 Перед Заюшкиным отъездом в Тюмень-1
# 45 jpg files in subdirectory
# years: 2010 - 2010 ; months: 5 - 5 ; days: 16 - 16
#
# 60
# D:\Photo\2010.05.29 ДР Мишгана
# 238 jpg files in subdirectory
# years: 2010 - 2010 ; months: 5 - 5 ; days: 29 - 29
#
# 61
# D:\Photo\2010.06.03 Метрополис
# 60 jpg files in subdirectory
# years: 2010 - 2010 ; months: 6 - 6 ; days: 5 - 5
#
# 62
# D:\Photo\2010.06.05 Альфа-Банк-летний праздник
# 16 jpg files in subdirectory
# years: 2010 - 2010 ; months: 6 - 6 ; days: 5 - 5
#
# 63
# D:\Photo\2010.06.06 Мамочка
# 5 jpg files in subdirectory
# years: 2010 - 2010 ; months: 6 - 6 ; days: 6 - 6
#
# 64
# D:\Photo\2010.06.07 Рабочая тема
# 68 jpg files in subdirectory
# years: 2010 - 2010 ; months: 6 - 6 ; days: 7 - 8
#
# 65
# D:\Photo\2010.06.09 Первый поход за платьем
# 12 jpg files in subdirectory
# years: 2010 - 2010 ; months: 6 - 6 ; days: 9 - 9
#
# 66
# D:\Photo\2010.06.09 Работка
# 22 jpg files in subdirectory
# years: 2010 - 2010 ; months: 6 - 6 ; days: 9 - 9
#
# 67
# D:\Photo\2010.06.19 Колбасята
# 94 jpg files in subdirectory
# years: 2010 - 2010 ; months: 6 - 6 ; days: 19 - 19
#
# 68
# D:\Photo\2010.06.22 Поход с мамой за платьем
# 43 jpg files in subdirectory
# years: 2010 - 2010 ; months: 6 - 6 ; days: 22 - 22
#
# 69
# D:\Photo\2010.06.23 Зайцы подарили розочку
# 10 jpg files in subdirectory
# years: 2010 - 2010 ; months: 6 - 6 ; days: 23 - 23
#
# 70
# D:\Photo\2010.06.24 Работка
# 63 jpg files in subdirectory
# years: 2010 - 2010 ; months: 6 - 6 ; days: 24 - 24
#
# 71
# D:\Photo\2010.06.25 Поход за платьем с Оксиком
# 24 jpg files in subdirectory
# years: 2010 - 2010 ; months: 6 - 6 ; days: 25 - 25
#
# 72
# D:\Photo\2010.06.27 Поход за платьем с мамой
# 4 jpg files in subdirectory
# years: 2010 - 2010 ; months: 6 - 6 ; days: 27 - 27
#
# 73
# D:\Photo\2010.07.04 Дача
# 96 jpg files in subdirectory
# years: 2010 - 2010 ; months: 7 - 7 ; days: 4 - 4
#
# 74
# D:\Photo\2010.07.10-11 Илюшка и Анютка в Москве
# 3 jpg files in subdirectory
# years: 2010 - 2010 ; months: 7 - 7 ; days: 10 - 10
#
# 75
# D:\Photo\2010.07.14 Ресницы
# 38 jpg files in subdirectory
# years: 2010 - 2010 ; months: 7 - 7 ; days: 15 - 22
#
# 76
# D:\Photo\2010.07.24 Дача с родителями
# 335 jpg files in subdirectory
# years: 2010 - 2010 ; months: 7 - 7 ; days: 24 - 26
#
# 77
# D:\Photo\2010.07.30 Новые шортики
# 9 jpg files in subdirectory
# years: 2010 - 2010 ; months: 7 - 7 ; days: 31 - 31
#
# 78
# D:\Photo\2010.08.13 ДР-27+девичник
# 274 jpg files in subdirectory
# years: 2010 - 2010 ; months: 8 - 8 ; days: 13 - 13
#
# 79
# D:\Photo\2010.08.19 Подготовка к свадьбе
# 349 jpg files in subdirectory
# years: 2010 - 2010 ; months: 8 - 8 ; days: 19 - 19
#
# 80
# D:\Photo\2010.08.21 Наша свадьба, день первый
# 3361 jpg files in subdirectory
# years: 2010 - 2010 ; months: 8 - 8 ; days: 21 - 21
#
# 81
# D:\Photo\2010.08.21-22 Свабдя
# 1070 jpg files in subdirectory
# years: 2010 - 2010 ; months: 8 - 8 ; days: 21 - 22
#
# 82
# D:\Photo\2010.08.23-31 Барселооона
# 1101 jpg files in subdirectory
# years: 2010 - 2010 ; months: 8 - 8 ; days: 23 - 23
#
# 83
# D:\Photo\2010.08.31-09.11 Майорка
# 1152 jpg files in subdirectory
# years: 2007 - 2010 ; months: 1 - 9 ; days: 1 - 31
#
# 84
# D:\Photo\2010.10.6-10 Новый Уренгой
# 119 jpg files in subdirectory
# years: 2010 - 2010 ; months: 10 - 10 ; days: 6 - 10
#
# 85
# D:\Photo\2010.10.09 Осень
# 341 jpg files in subdirectory
# years: 2010 - 2010 ; months: 10 - 10 ; days: 9 - 9
#
# 86
# D:\Photo\2010.10.16 Караоке
# 42 jpg files in subdirectory
# years: 2010 - 2010 ; months: 10 - 10 ; days: 16 - 16
#
# 87
# D:\Photo\2010.11.09 ДР 29 лет
# 5 jpg files in subdirectory
# years: 2010 - 2010 ; months: 11 - 11 ; days: 9 - 9
#
# 88
# D:\Photo\2010.12.31 Германия
# 530 jpg files in subdirectory
# years: 2010 - 2010 ; months: 12 - 12 ; days: 31 - 31
#
# 89
# D:\Photo\2011.01.22 Орхидеи
# 73 jpg files in subdirectory
# years: 2011 - 2011 ; months: 1 - 1 ; days: 8 - 22
#
# 90
# D:\Photo\2011.01.29 Бар вредных привычек
# 30 jpg files in subdirectory
# years: 2011 - 2011 ; months: 1 - 1 ; days: 29 - 29
#
# 91
# D:\Photo\2011.02.12 Встреча одноклассников Шк.3
# 132 jpg files in subdirectory
# years: 2011 - 2011 ; months: 2 - 2 ; days: 6 - 13
#
# 92
# D:\Photo\2011.02.18 23 Омск
# 226 jpg files in subdirectory
# years: 2011 - 2011 ; months: 2 - 2 ; days: 18 - 18
#
# 93
# D:\Photo\2011.02.23 Родители в гостях
# 13 jpg files in subdirectory
# years: 2011 - 2011 ; months: 2 - 2 ; days: 23 - 23
#
# 94
# D:\Photo\2011.03.04 Масленница, к зятю на блины
# 7 jpg files in subdirectory
# years: 2011 - 2011 ; months: 3 - 3 ; days: 4 - 4
#
# 95
# D:\Photo\2011.03.05 8 марта
# 56 jpg files in subdirectory
# years: 2011 - 2011 ; months: 3 - 3 ; days: 6 - 7
#
# 96
# D:\Photo\2011.03.06 Мартовские коты
# 6 jpg files in subdirectory
# years: 2011 - 2011 ; months: 2 - 2 ; days: 27 - 27
#
# 97
# D:\Photo\2011.03.08 С родителями
# 13 jpg files in subdirectory
# years: 2011 - 2011 ; months: 3 - 3 ; days: 8 - 9
#
# 98
# D:\Photo\2011.03.13 В гостях у родителей мы и Надежда Егоровна
# 63 jpg files in subdirectory
# years: 2011 - 2011 ; months: 3 - 3 ; days: 11 - 13
#
# 99
# D:\Photo\2011.04 Макияжики
# 84 jpg files in subdirectory
# years: 2011 - 2011 ; months: 4 - 5 ; days: 14 - 28
#
# 100
# D:\Photo\2011.05.01 Дача
# 78 jpg files in subdirectory
# years: 2011 - 2011 ; months: 5 - 5 ; days: 1 - 9
#
# 101
# D:\Photo\2011.05.18 Белая Шабака
# 42 jpg files in subdirectory
# years: 2011 - 2011 ; months: 5 - 5 ; days: 20 - 20
#
# 102
# D:\Photo\2011.05.23-27_Курсы фотографии
# 29 jpg files in subdirectory
# years: 2011 - 2011 ; months: 5 - 5 ; days: 23 - 27
#
# 103
# D:\Photo\2011.05.27 Заяц приехал из Тюмени. Царицыно
# 85 jpg files in subdirectory
# years: 2011 - 2011 ; months: 5 - 5 ; days: 27 - 27
#
# 104
# D:\Photo\2011.05.31 Тетя Валя
# 10 jpg files in subdirectory
# years: 2011 - 2011 ; months: 5 - 6 ; days: 1 - 31
#
# 105
# D:\Photo\2011.06.05 Шашлыки с родителями
# 189 jpg files in subdirectory
# years: 2011 - 2011 ; months: 6 - 6 ; days: 5 - 6
#
# 106
# D:\Photo\2011.06.11-12 Дача
# 70 jpg files in subdirectory
# years: 2011 - 2011 ; months: 6 - 6 ; days: 11 - 13
#
# 107
# D:\Photo\2011.06.18-19 At Masha's
# 84 jpg files in subdirectory
# years: 2011 - 2011 ; months: 6 - 6 ; days: 18 - 19
#
# 108
# D:\Photo\2011.06.25-26 Дача с родителями и Катей
# 263 jpg files in subdirectory
# years: 2011 - 2011 ; months: 6 - 6 ; days: 25 - 25
#
# 109
# D:\Photo\2011.07.08-24 Крым 2011
# 936 jpg files in subdirectory
# years: 2011 - 2011 ; months: 7 - 7 ; days: 8 - 24
#
# 110
# D:\Photo\2011.07.30-31 Дача с родителями и Катей-2
# 251 jpg files in subdirectory
# years: 2011 - 2011 ; months: 7 - 7 ; days: 30 - 31
#
# 111
# D:\Photo\2011.08.13 Днюха-ха!
# 396 jpg files in subdirectory
# years: 2011 - 2011 ; months: 8 - 8 ; days: 13 - 13
#
# 112
# D:\Photo\2011.08.19-21 Дача. Ситцевая Свадьба
# 359 jpg files in subdirectory
# years: 2011 - 2011 ; months: 8 - 8 ; days: 20 - 20
#
# 113
# D:\Photo\2011.08.26 Свадьба Саши и Оксаны
# 23 jpg files in subdirectory
# years: 2011 - 2011 ; months: 8 - 8 ; days: 26 - 26
#
# 114
# D:\Photo\2011.08.28 Хрыбочки
# 48 jpg files in subdirectory
# years: 2011 - 2011 ; months: 8 - 8 ; days: 28 - 28
#
# 115
# D:\Photo\2011.08.31 Лицо Альфа-Банка
# 16 jpg files in subdirectory
# years: 2011 - 2011 ; months: 8 - 8 ; days: 31 - 31
#
# 116
# D:\Photo\2011.09.04 Альфа-Шоу 4D
# 99 jpg files in subdirectory
# years: 2011 - 2011 ; months: 9 - 9 ; days: 5 - 5
#
# 117
# D:\Photo\2011.09.10 Кыйив
# 127 jpg files in subdirectory
# years: 2011 - 2011 ; months: 9 - 9 ; days: 10 - 10
#
# 118
# D:\Photo\2011.09.10-21 Крым
# 1096 jpg files in subdirectory
# years: 2011 - 2011 ; months: 9 - 9 ; days: 15 - 15
#
# 119
# D:\Photo\2011.09.21-25 Ростов. Рыбалка
# 394 jpg files in subdirectory
# years: 2011 - 2011 ; months: 9 - 9 ; days: 22 - 24
#
# 120
# D:\Photo\2011.10.01 Дача. грибная охота
# 43 jpg files in subdirectory
# years: 2011 - 2011 ; months: 10 - 10 ; days: 1 - 1
#
# 121
# D:\Photo\2011.10.08 Шашлыки с друзьями
# 27 jpg files in subdirectory
# years: 2011 - 2011 ; months: 10 - 10 ; days: 8 - 8
#
# 122
# D:\Photo\2011.10.27 Канадцы
# 35 jpg files in subdirectory
# years: 2011 - 2011 ; months: 10 - 10 ; days: 22 - 27
#
# 123
# D:\Photo\2011.11.05 Денвер
# 64 jpg files in subdirectory
# years: 2011 - 2011 ; months: 10 - 11 ; days: 3 - 31
#
# 124
# D:\Photo\2011.11.9-16 Germany
# 1512 jpg files in subdirectory
# years: 2011 - 2011 ; months: 11 - 11 ; days: 9 - 9
#
# 125
# D:\Photo\2011.12.04 У Таниных
# 20 jpg files in subdirectory
# years: 2011 - 2011 ; months: 12 - 12 ; days: 4 - 17
#
# 126
# D:\Photo\2011.12.19 Юлькин ДР
# 18 jpg files in subdirectory
# years: 2011 - 2011 ; months: 12 - 12 ; days: 19 - 19
#
# 127
# D:\Photo\2011.12.23 Корпоратив Альфы
# 172 jpg files in subdirectory
# years: 2011 - 2011 ; months: 12 - 12 ; days: 23 - 23
#
# 128
# D:\Photo\2012.01.01 НГ
# 177 jpg files in subdirectory
# years: 2012 - 2012 ; months: 1 - 1 ; days: 1 - 1
#
# 129
# D:\Photo\2012.01.16 Афимолл с Катюшкой
# 32 jpg files in subdirectory
# years: 2012 - 2012 ; months: 1 - 1 ; days: 16 - 16
#
# 130
# D:\Photo\2012.01.29 Встреча с Ксюшей
# 7 jpg files in subdirectory
# years: 2012 - 2012 ; months: 1 - 1 ; days: 29 - 29
#
# 131
# D:\Photo\2012.02.11 Родители у нас в гостях, покер, настольные игры
# 9 jpg files in subdirectory
# years: 2012 - 2012 ; months: 2 - 2 ; days: 11 - 12
#
# 132
# D:\Photo\2012.02.14 День влюбленных на кораблике
# 111 jpg files in subdirectory
# years: 2012 - 2012 ; months: 2 - 2 ; days: 14 - 15
#
# 133
# D:\Photo\2012.02.26-04.21 Ранняя весна в Москве, лыжи, прогулки
# 68 jpg files in subdirectory
# years: 2012 - 2012 ; months: 2 - 4 ; days: 3 - 26
#
# 134
# D:\Photo\2012.03.04 О спорт ты мир!
# 36 jpg files in subdirectory
# years: 2012 - 2012 ; months: 3 - 3 ; days: 4 - 4
#
# 135
# D:\Photo\2012.03.08 8 марта у родителей
# 39 jpg files in subdirectory
# years: 2012 - 2012 ; months: 3 - 3 ; days: 8 - 9
#
# 136
# D:\Photo\2012.05.12-26 Командировочка в Канаду
# 195 jpg files in subdirectory
# years: 2012 - 2012 ; months: 5 - 5 ; days: 12 - 26
#
# 137
# D:\Photo\2012.06.07-10 Питер у Макса на ДР
# 451 jpg files in subdirectory
# years: 2012 - 2012 ; months: 6 - 6 ; days: 7 - 10
#
# 138
# D:\Photo\2012.06.16-24 Франция
# 900 jpg files in subdirectory
# years: 2012 - 2012 ; months: 6 - 6 ; days: 17 - 24
#
# 139
# D:\Photo\2012.07.14-15 Папа юбилей 60 лет
# 367 jpg files in subdirectory
# years: 2012 - 2012 ; months: 7 - 7 ; days: 12 - 15
#
# 140
# D:\Photo\2012.08.18_Дача никто не приезжача
# 96 jpg files in subdirectory
# years: 2012 - 2012 ; months: 7 - 8 ; days: 18 - 26
#
# 141
# D:\Photo\2012.08.25 Сальсатеплоход
# 62 jpg files in subdirectory
# years: 2012 - 2012 ; months: 8 - 8 ; days: 25 - 26
#
# 142
# D:\Photo\2012.09-10 Родители, Крым, Омск
# 847 jpg files in subdirectory
# years: 2010 - 2010 ; months: 5 - 7 ; days: 1 - 28
#
# 143
# D:\Photo\2012.10.05-19 Вьетнам
# 922 jpg files in subdirectory
# years: 2012 - 2012 ; months: 10 - 10 ; days: 10 - 10
#
# 144
# D:\Photo\2012.12.01 Мама юбилей 55 лет
# 78 jpg files in subdirectory
# years: 2012 - 2012 ; months: 12 - 12 ; days: 1 - 2
#
# 145
# D:\Photo\2012.12.21 Корпоратив Альфа-Банка
# 49 jpg files in subdirectory
# years: 2012 - 2012 ; months: 12 - 12 ; days: 21 - 21
# Warning!!! Some files with creation time == None in the directory
#
# 146
# D:\Photo\Evgeny Iphone backup folder
# 104 jpg files in subdirectory
# years: 2014 - 2017 ; months: 1 - 12 ; days: 1 - 30
# Warning!!! Some files with creation time == None in the directory
#
# 147
# D:\Photo\2016.12.09 Детский Новый год
# 149 jpg files in subdirectory
# years: 2016 - 2016 ; months: 12 - 12 ; days: 8 - 9
#
# 148
# D:\Photo\2013.01.07 Рождество у Таниных с Жениными
# 5 jpg files in subdirectory
# years: 2013 - 2013 ; months: 1 - 1 ; days: 8 - 8
#
# 149
# D:\Photo\2013.02 Тетя Аля
# 34 jpg files in subdirectory
# years: 2013 - 2013 ; months: 1 - 2 ; days: 9 - 26
#
# 150
# D:\Photo\2013.05.02-04 Казань
# 124 jpg files in subdirectory
# years: 2013 - 2013 ; months: 5 - 5 ; days: 3 - 4
#
# 151
# D:\Photo\2013.05.09-12 День победы на даче со всеми
# 107 jpg files in subdirectory
# years: 2013 - 2013 ; months: 5 - 5 ; days: 9 - 12
#
# 152
# D:\Photo\2013.05.22 Радуга-дуга
# 23 jpg files in subdirectory
# years: 2013 - 2013 ; months: 5 - 5 ; days: 23 - 23
#
# 153
# D:\Photo\2013.06.07-13 Питер
# 1367 jpg files in subdirectory
# years: 2013 - 2013 ; months: 6 - 6 ; days: 10 - 10
#
# 154
# D:\Photo\2013.06.15 Свадьба Аллы и Миши
# 310 jpg files in subdirectory
# years: 2013 - 2013 ; months: 6 - 6 ; days: 15 - 16
# Warning!!! Some files with creation time == None in the directory
#
# 155
# D:\Photo\2013.06.29-07.07 Escape to Crimea
# 273 jpg files in subdirectory
# years: 2013 - 2013 ; months: 7 - 7 ; days: 4 - 4
#
# 156
# D:\Photo\2013.07.14 Дача родители
# 135 jpg files in subdirectory
# years: 2013 - 2013 ; months: 7 - 7 ; days: 13 - 14
#
# 157
# D:\Photo\2013.08.13 Угадайкачё
# 26 jpg files in subdirectory
# years: 2013 - 2013 ; months: 8 - 8 ; days: 13 - 14
#
# 158
# D:\Photo\2013.08.23-25 Рыбалка в Калужской обл
# 176 jpg files in subdirectory
# years: 2013 - 2013 ; months: 8 - 8 ; days: 23 - 25
#
# 159
# D:\Photo\2013.09.04-22 USA
# 6702 jpg files in subdirectory
# years: 2013 - 2013 ; months: 9 - 9 ; days: 15 - 15
#
# 160
# D:\Photo\2013.09.29 Бабулин ДР
# 74 jpg files in subdirectory
# years: 2013 - 2013 ; months: 9 - 9 ; days: 29 - 29
#
# 161
# D:\Photo\2013.11.08 УгадайЧё
# 54 jpg files in subdirectory
# years: 2013 - 2013 ; months: 11 - 11 ; days: 8 - 10
#
# 162
# D:\Photo\2013.11.16 Тонка!!!
# 128 jpg files in subdirectory
# years: 2013 - 2013 ; months: 11 - 11 ; days: 16 - 16
#
# 163
# D:\Photo\2013.11.30 Мама ДР
# 22 jpg files in subdirectory
# years: 2013 - 2013 ; months: 11 - 12 ; days: 1 - 30
#
# 164
# D:\Photo\2014.01.01 Ыталия
# 3445 jpg files in subdirectory
# years: 2013 - 2013 ; months: 12 - 12 ; days: 31 - 31
#
# 165
# D:\Photo\2014.01-10 Беременность
# 1582 jpg files in subdirectory
# years: 2014 - 2014 ; months: 5 - 10 ; days: 1 - 31
#
# 166
# D:\Photo\2014.02-... Сауди
# 33 jpg files in subdirectory
# years: 2014 - 2016 ; months: 2 - 5 ; days: 9 - 28
#
# 167
# D:\Photo\2014.05.30-31 Бахренй
# 163 jpg files in subdirectory
# years: 2014 - 2014 ; months: 5 - 5 ; days: 31 - 31
#
# 168
# D:\Photo\2014.06.06 Бахран
# 29 jpg files in subdirectory
# years: 2014 - 2014 ; months: 6 - 6 ; days: 6 - 7
#
# 169
# D:\Photo\2014.07.02-16 Гермавстрия
# 2150 jpg files in subdirectory
# years: 2014 - 2014 ; months: 7 - 7 ; days: 10 - 10
#
# 170
# D:\Photo\2014.07.25-30 Дубаё
# 555 jpg files in subdirectory
# years: 2014 - 2014 ; months: 7 - 7 ; days: 25 - 25
#
# 171
# D:\Photo\2014.08.15-16 ДР в Бахрейне
# 39 jpg files in subdirectory
# years: 2014 - 2014 ; months: 8 - 8 ; days: 15 - 16
#
# 172
# D:\Photo\2014.09.02-13 Хранция
# 538 jpg files in subdirectory
# years: 2014 - 2014 ; months: 9 - 9 ; days: 2 - 12
#
# 173
# D:\Photo\2014.10.28 - 01.27 Беременята
# 748 jpg files in subdirectory
# years: 2014 - 2014 ; months: 2 - 11 ; days: 1 - 31
# Warning!!! Some files with creation time == None in the directory
#
# 174
# D:\Photo\2014.11.05 Доча до пол годика
# 9982 jpg files in subdirectory
# years: 2012 - 2015 ; months: 1 - 12 ; days: 1 - 31
# Warning!!! Some files with creation time == None in the directory
#
# 175
# D:\Photo\2015.02.12 Ernest's Birthday
# 17 jpg files in subdirectory
# years: 2015 - 2015 ; months: 2 - 2 ; days: 12 - 12
#
# 176
# D:\Photo\2015.03.01 Deny's Birthday
# 25 jpg files in subdirectory
# years: 2015 - 2015 ; months: 3 - 3 ; days: 1 - 1
#
# 177
# D:\Photo\2015.03.08-22 Германия
# 3861 jpg files in subdirectory
# years: 2015 - 2015 ; months: 3 - 3 ; days: 15 - 15
#
# 178
# D:\Photo\2015.04.08 Visit to Irina
# 81 jpg files in subdirectory
# years: 2015 - 2015 ; months: 4 - 4 ; days: 8 - 8
#
# 179
# D:\Photo\2015.04.15 Visit to Yulia
# 21 jpg files in subdirectory
# years: 2015 - 2015 ; months: 4 - 4 ; days: 18 - 18
#
# 180
# D:\Photo\2015.04.17 Agata's party
# 224 jpg files in subdirectory
# years: 2015 - 2015 ; months: 4 - 4 ; days: 17 - 17
#
# 181
# D:\Photo\2015.04.23 Adelina's party
# 33 jpg files in subdirectory
# years: 2015 - 2015 ; months: 4 - 4 ; days: 23 - 23
#
# 182
# D:\Photo\2015.04.25 Katia & Tim pool-party
# 114 jpg files in subdirectory
# years: 2015 - 2015 ; months: 4 - 4 ; days: 24 - 24
#
# 183
# D:\Photo\2015.05.05 Доча Пол Годика - Год
# 5843 jpg files in subdirectory
# years: 2015 - 2015 ; months: 5 - 11 ; days: 1 - 31
# Warning!!! Some files with creation time == None in the directory
#
# 184
# D:\Photo\2015.05.29-09.13 Москва
# 3977 jpg files in subdirectory
# years: 2015 - 2015 ; months: 5 - 8 ; days: 8 - 31
#
# 185
# D:\Photo\2015.06.12-07 Дача
# 421 jpg files in subdirectory
# years: 2015 - 2015 ; months: 6 - 6 ; days: 7 - 12
#
# 186
# D:\Photo\2015.07.23-17 Дача с Женей + банный день
# 550 jpg files in subdirectory
# years: 2015 - 2015 ; months: 7 - 7 ; days: 18 - 23
#
# 187
# D:\Photo\2015.07.29-08.12 Испания
# 7709 jpg files in subdirectory
# years: 2015 - 2015 ; months: 7 - 7 ; days: 30 - 30
#
# 188
# D:\Photo\2015.08.12 Вена
# 100 jpg files in subdirectory
# years: 2015 - 2015 ; months: 8 - 8 ; days: 12 - 12
#
# 189
# D:\Photo\2015.08.30-26 Дача
# 636 jpg files in subdirectory
# years: 2015 - 2015 ; months: 8 - 8 ; days: 26 - 29
#
# 190
# D:\Photo\2015.09.05 Дача последняя
# 66 jpg files in subdirectory
# years: 2015 - 2015 ; months: 9 - 9 ; days: 5 - 5
#
# 191
# D:\Photo\2015.09.13-27 Турция
# 2732 jpg files in subdirectory
# years: 2015 - 2015 ; months: 9 - 9 ; days: 8 - 28
# Warning!!! Some files with creation time == None in the directory
#
# 192
# D:\Photo\2015.11.05 Первый дочин День рождения
# 170 jpg files in subdirectory
# years: 2015 - 2015 ; months: 11 - 11 ; days: 4 - 5
#
# 193
# D:\Photo\2015.11.05-2016.05.05 Доча год-полтора
# 3675 jpg files in subdirectory
# years: 2015 - 2016 ; months: 1 - 12 ; days: 1 - 31
# Warning!!! Some files with creation time == None in the directory
#
# 194
# D:\Photo\2015.11.15 Даммам
# 153 jpg files in subdirectory
# years: 2015 - 2015 ; months: 11 - 11 ; days: 15 - 15
#
# 195
# D:\Photo\2015.11.2015 Farewall party Ira & Marat
# 67 jpg files in subdirectory
# years: 2015 - 2015 ; months: 11 - 11 ; days: 20 - 20
#
# 196
# D:\Photo\2015.12.04 Бахрейн (зоопарк)
# 130 jpg files in subdirectory
# years: 2015 - 2015 ; months: 12 - 12 ; days: 4 - 4
#
# 197
# D:\Photo\2015.12.18 Бахрейн (Форт утренний)
# 93 jpg files in subdirectory
# years: 2015 - 2015 ; months: 12 - 12 ; days: 18 - 18
#
# 198
# D:\Photo\2015.12.22 Свадьба Кати и Жени Некоторые фотки
# 399 jpg files in subdirectory
# years: 2015 - 2015 ; months: 12 - 12 ; days: 22 - 23
#
# 199
# D:\Photo\2015.12.22 Свадьба Кати и Жени(видеооткрытка и фото от дочи)
# 30 jpg files in subdirectory
# years: 2015 - 2015 ; months: 12 - 12 ; days: 22 - 22
#
# 200
# D:\Photo\2015.12.27-2016.01 Родители приехали
# 2185 jpg files in subdirectory
# years: 2015 - 2016 ; months: 1 - 12 ; days: 1 - 31
#
# 201
# D:\Photo\2016.01.21 Новогодняя семейная фотосессия
# 247 jpg files in subdirectory
# years: 2016 - 2016 ; months: 1 - 1 ; days: 21 - 21
#
# 202
# D:\Photo\2016.02.14-19 KAUST
# 53 jpg files in subdirectory
# years: 2016 - 2016 ; months: 2 - 2 ; days: 14 - 17
#
# 203
# D:\Photo\2016.03.08 Женский день
# 61 jpg files in subdirectory
# years: 2016 - 2016 ; months: 3 - 3 ; days: 8 - 8
#
# 204
# D:\Photo\2016.03.09 Дождь в Сауди
# 12 jpg files in subdirectory
# years: 2016 - 2016 ; months: 3 - 3 ; days: 9 - 9
#
# 205
# D:\Photo\2016.03.10-19 Оман
# 2176 jpg files in subdirectory
# years: 2016 - 2016 ; months: 3 - 3 ; days: 15 - 15
#
# 206
# D:\Photo\2016.04.02 Дельфинарий
# 53 jpg files in subdirectory
# years: 2016 - 2016 ; months: 4 - 4 ; days: 2 - 2
#
# 207
# D:\Photo\2016.04.13 Фотосессия Лизы в красивом платье и с тазиком
# 405 jpg files in subdirectory
# years: 2016 - 2016 ; months: 4 - 4 ; days: 13 - 13
#
# 208
# D:\Photo\2016.04.22-24 Живительный Бахрейн
# 336 jpg files in subdirectory
# years: 2016 - 2016 ; months: 4 - 4 ; days: 23 - 24
#
# 209
# D:\Photo\2016.04.24 Фото на Визу Лиза
# 7 jpg files in subdirectory
# years: 2016 - 2016 ; months: 4 - 4 ; days: 24 - 24
#
# 210
# D:\Photo\2016.04.27 Токинг-монинг
# 23 jpg files in subdirectory
# years: 2016 - 2016 ; months: 4 - 4 ; days: 27 - 27
#
# 211
# D:\Photo\2016.05.10 Фотосессия Лизы в трубе и с большим белым мишкой
# 40 jpg files in subdirectory
# years: 2016 - 2016 ; months: 5 - 5 ; days: 9 - 10
#
# 212
# D:\Photo\2016.05.13-29 Бенилю
# 1949 jpg files in subdirectory
# years: 2016 - 2016 ; months: 5 - 5 ; days: 13 - 28
#
# 213
# D:\Photo\2016.06-09 Лето в Москве
# 5936 jpg files in subdirectory
# years: 2016 - 2016 ; months: 5 - 9 ; days: 2 - 31
#
# 214
# D:\Photo\2016.09-2015.05 Сауди 3 сезон
# 19 jpg files in subdirectory
# years: 2016 - 2017 ; months: 1 - 10 ; days: 7 - 12
#
# 215
# D:\Photo\2016.11.05,10 Лизуну 2 года
# 203 jpg files in subdirectory
# years: 2016 - 2016 ; months: 11 - 11 ; days: 5 - 10
#
# 216
# D:\Photo\2016.11.11-13 Катар
# 138 jpg files in subdirectory
# years: 2016 - 2016 ; months: 11 - 11 ; days: 12 - 13
#
# 217
# D:\Photo\2020.06.13-14 Cotswlds, Oxford, Cambridge
# 972 jpg files in subdirectory
# years: 2020 - 2020 ; months: 6 - 6 ; days: 13 - 14
#
# 218
# D:\Photo\2017 Новый год у Айдагулловых
# 39 jpg files in subdirectory
# years: 2016 - 2017 ; months: 1 - 12 ; days: 1 - 31
#
# 219
# D:\Photo\2017.01.14 Хофуф. Пещеры
# 99 jpg files in subdirectory
# years: 2017 - 2017 ; months: 1 - 1 ; days: 14 - 14
#
# 220
# D:\Photo\2017.01.21 Лошадки
# 111 jpg files in subdirectory
# years: 2017 - 2017 ; months: 1 - 1 ; days: 21 - 21
#
# 221
# D:\Photo\2017.01.30 Новогодняя фотосессия Лизы - зайчик
# 104 jpg files in subdirectory
# years: 2017 - 2017 ; months: 1 - 1 ; days: 30 - 30
#
# 222
# D:\Photo\2017.02.03 Новогодняя фотосессия Лизы - Маленький Санта
# 132 jpg files in subdirectory
# years: 2017 - 2017 ; months: 2 - 2 ; days: 3 - 3
#
# 223
# D:\Photo\2017.02.04 Семейная фотосессия в белом
# 50 jpg files in subdirectory
# years: 2017 - 2017 ; months: 2 - 2 ; days: 4 - 4
#
# 224
# D:\Photo\2017.02.11 International Day
# 221 jpg files in subdirectory
# years: 2017 - 2017 ; months: 2 - 2 ; days: 11 - 11
#
# 225
# D:\Photo\2017.02.25 Фотосессия It's a boy
# 110 jpg files in subdirectory
# years: 2017 - 2017 ; months: 2 - 2 ; days: 25 - 25
#
# 226
# D:\Photo\2017.02.25 ФОтосессия Масленица в народных костюмах
# 107 jpg files in subdirectory
# years: 2017 - 2017 ; months: 2 - 2 ; days: 25 - 25
#
# 227
# D:\Photo\2017.02.25 Экскурсия по Хобару - фламинго, Desert Design
# 149 jpg files in subdirectory
# years: 2017 - 2017 ; months: 2 - 2 ; days: 25 - 25
#
# 228
# D:\Photo\2017.02.28 Фотосессия Лизы - 2-летняя Фиалковая Фея
# 121 jpg files in subdirectory
# years: 2017 - 2017 ; months: 2 - 2 ; days: 28 - 28
#
# 229
# D:\Photo\2017.02.28 Хофуф. Пещеры со Светланой Викторовной
# 84 jpg files in subdirectory
# years: 2017 - 2017 ; months: 2 - 2 ; days: 28 - 28
#
# 230
# D:\Photo\2017.03.03 Поездка в Окаир форт и Окаир бич
# 159 jpg files in subdirectory
# years: 2017 - 2017 ; months: 3 - 3 ; days: 3 - 3
#
# 231
# D:\Photo\2017.03.04 Закат в Даммаме
# 10 jpg files in subdirectory
# years: 2017 - 2017 ; months: 3 - 3 ; days: 4 - 4
#
# 232
# D:\Photo\2017.03.06 Фотосессия Лиза и пузо
# 9 jpg files in subdirectory
# years: 2017 - 2017 ; months: 3 - 3 ; days: 6 - 6
#
# 233
# D:\Photo\2017.03.18 Поездка на Окаир Бич с Маргаритой Геннадьевной и американцами
# 68 jpg files in subdirectory
# years: 2017 - 2017 ; months: 3 - 3 ; days: 18 - 18
#
# 234
# D:\Photo\2017.03.20 Данька роды и первый месяц
# 305 jpg files in subdirectory
# years: 2017 - 2017 ; months: 3 - 4 ; days: 20 - 29
#
# 235
# D:\Photo\2017.05.07 Фотосессия Два зайки (Лиза и Даня)
# 113 jpg files in subdirectory
# years: 2017 - 2017 ; months: 5 - 5 ; days: 7 - 7
#
# 236
# D:\Photo\2017.05.08 Поездка в пещеры Хофуфа с Алексеем Алексеевичем
# 132 jpg files in subdirectory
# years: 2017 - 2017 ; months: 5 - 5 ; days: 8 - 8
#
# 237
# D:\Photo\2017.06-08 Каникулы в Москве
# 177 jpg files in subdirectory
# years: 2017 - 2017 ; months: 7 - 8 ; days: 6 - 25
#
# 238
# D:\Photo\2017.07.02 Паулинин ДР
# 395 jpg files in subdirectory
# years: 2017 - 2017 ; months: 7 - 7 ; days: 2 - 2
#
# 239
# D:\Photo\2017.07.20 Фотосессия Даня-мишка 4 мес
# 71 jpg files in subdirectory
# years: 2017 - 2017 ; months: 7 - 7 ; days: 20 - 20
#
# 240
# D:\Photo\2017.09.06-13 Чехия
# 291 jpg files in subdirectory
# years: 2017 - 2017 ; months: 9 - 9 ; days: 11 - 12
#
# 241
# D:\Photo\2017.09.13-18 Германия
# 441 jpg files in subdirectory
# years: 2017 - 2017 ; months: 9 - 9 ; days: 13 - 17
#
# 242
# D:\Photo\2017.09.18-21 Швейцария
# 1044 jpg files in subdirectory
# years: 2017 - 2017 ; months: 9 - 9 ; days: 18 - 20
#
# 243
# D:\Photo\2017.09.21-24 Италия
# 172 jpg files in subdirectory
# years: 2017 - 2017 ; months: 9 - 9 ; days: 21 - 23
#
# 244
# D:\Photo\2017.10.25 Лизин Хэллоуин
# 86 jpg files in subdirectory
# years: 2017 - 2017 ; months: 10 - 10 ; days: 25 - 26
#
# 245
# D:\Photo\2017.11.08-18 Лизин ДР (дома, в саду, вечеринка, фотосет)
# 738 jpg files in subdirectory
# years: 2017 - 2017 ; months: 11 - 11 ; days: 5 - 18
#
# 246
# D:\Photo\2017.12.08 Детская елка
# 859 jpg files in subdirectory
# years: 2017 - 2017 ; months: 12 - 12 ; days: 8 - 8
#
# 247
# D:\Photo\2017.12.08 Детский Новый год в Аль-Рушаид
# 859 jpg files in subdirectory
# years: 2017 - 2017 ; months: 12 - 12 ; days: 8 - 8
#
# 248
# D:\Photo\2017.12.30 Укаир-бич с Айдагулловыми
# 147 jpg files in subdirectory
# years: 2017 - 2017 ; months: 12 - 12 ; days: 30 - 30
#
# 249
# D:\Photo\2017.12.31 Новый год с Айдагулловыми
# 14 jpg files in subdirectory
# years: 2017 - 2017 ; months: 12 - 12 ; days: 31 - 31
#
# 250
# D:\Photo\2017-2018 сезон в Сауди Данины фотки
# 501 jpg files in subdirectory
# years: 2017 - 2018 ; months: 1 - 12 ; days: 4 - 26
#
# 251
# D:\Photo\2017-2018 сезон в Сауди Лизины фотки
# 17 jpg files in subdirectory
# years: 2017 - 2018 ; months: 1 - 10 ; days: 17 - 24
#
# 252
# D:\Photo\2017-2018 сезон в Сауди разное
# 86 jpg files in subdirectory
# years: 2017 - 2018 ; months: 4 - 12 ; days: 1 - 20
#
# 253
# D:\Photo\2018.01.13 Джубэил со Светланой Викторовной
# 34 jpg files in subdirectory
# years: 2018 - 2018 ; months: 1 - 1 ; days: 13 - 13
#
# 254
# D:\Photo\2018.01.27 Укаир-бич со Светланой Викторовной
# 147 jpg files in subdirectory
# years: 2018 - 2018 ; months: 1 - 1 ; days: 27 - 27
#
# 255
# D:\Photo\2018.02.03 Семейная Новогодняя фотосессия
# 258 jpg files in subdirectory
# years: 2018 - 2018 ; months: 2 - 2 ; days: 3 - 3
#
# 256
# D:\Photo\2018.02.05-06 Поездка в Бахрейн со Светланой Викторовной
# 255 jpg files in subdirectory
# years: 2018 - 2018 ; months: 2 - 2 ; days: 5 - 6
#
# 257
# D:\Photo\2018.02.23 Пустыня
# 698 jpg files in subdirectory
# years: 2018 - 2018 ; months: 2 - 2 ; days: 23 - 23
#
# 258
# D:\Photo\2018.03.03 Бахрейн. Третий форт Арад
# 153 jpg files in subdirectory
# years: 2018 - 2018 ; months: 3 - 3 ; days: 3 - 3
#
# 259
# D:\Photo\2018.03.09 Uqair Beach with friends
# 299 jpg files in subdirectory
# years: 2018 - 2018 ; months: 3 - 3 ; days: 9 - 9
#
# 260
# D:\Photo\2018.03.10 Liza's photosession with flowers
# 42 jpg files in subdirectory
# years: 2018 - 2018 ; months: 3 - 3 ; days: 10 - 10
#
# 261
# D:\Photo\2018.03.15 Photosession of Daniel in necktie
# 124 jpg files in subdirectory
# years: 2018 - 2018 ; months: 3 - 3 ; days: 15 - 15
#
# 262
# D:\Photo\2018.03.18 Night view of Bahrain
# 106 jpg files in subdirectory
# years: 2018 - 2018 ; months: 3 - 3 ; days: 18 - 18
#
# 263
# D:\Photo\2018.03.20 Happy birthday Daniel
# 325 jpg files in subdirectory
# years: 2018 - 2018 ; months: 3 - 6 ; days: 2 - 22
#
# 264
# D:\Photo\2018.03.21 Наш backyard
# 14 jpg files in subdirectory
# years: 2018 - 2018 ; months: 2 - 3 ; days: 21 - 24
#
# 265
# D:\Photo\2018.03.26 Oman-Salalah
# 2025 jpg files in subdirectory
# years: 2018 - 2018 ; months: 3 - 3 ; days: 25 - 31
#
# 266
# D:\Photo\2018.05.25 Даня - хаусбой
# 9 jpg files in subdirectory
# years: 2018 - 2018 ; months: 5 - 5 ; days: 25 - 25
#
# 267
# D:\Photo\2018.06.06 Evgeny and Harold Farewell NightclubParty
# 49 jpg files in subdirectory
# years: 2018 - 2018 ; months: 6 - 6 ; days: 5 - 6
#
# 268
# D:\Photo\2018.06.06 Farewell с друзьями
# 7 jpg files in subdirectory
# years: 2018 - 2018 ; months: 6 - 6 ; days: 6 - 6
#
# 269
# D:\Photo\2018.06.06 Даня и Лиза поварята
# 56 jpg files in subdirectory
# years: 2018 - 2018 ; months: 6 - 6 ; days: 6 - 6
#
# 270
# D:\Photo\2018.06.07 Последний день в Бахрейне
# 5 jpg files in subdirectory
# years: 2018 - 2018 ; months: 6 - 6 ; days: 7 - 7
#
# 271
# D:\Photo\2018.06.07 Последний день в Сауди. Энни
# 59 jpg files in subdirectory
# years: 2018 - 2018 ; months: 6 - 6 ; days: 7 - 7
#
# 272
# D:\Photo\2018.06.08-26 Португалия
# 5281 jpg files in subdirectory
# years: 2018 - 2018 ; months: 6 - 6 ; days: 9 - 24
#
# 273
# D:\Photo\2018.06.30-07.01 Дача
# 93 jpg files in subdirectory
# years: 2018 - 2018 ; months: 6 - 7 ; days: 1 - 30
#
# 274
# D:\Photo\2018.08 Ночные виды из окна 14 этажа
# 58 jpg files in subdirectory
# years: 2018 - 2018 ; months: 8 - 8 ; days: 6 - 19
#
# 275
# D:\Photo\2018.08.13 Танин ДР
# 5 jpg files in subdirectory
# years: 2018 - 2018 ; months: 8 - 8 ; days: 13 - 13
#
# 276
# D:\Photo\2018.08.20 Даня на кровати
# 17 jpg files in subdirectory
# years: 2018 - 2018 ; months: 8 - 8 ; days: 20 - 20
#
# 277
# D:\Photo\2018.09.08 Лена фотографирует
# 368 jpg files in subdirectory
# years: 2018 - 2018 ; months: 9 - 9 ; days: 8 - 8
#
# 278
# D:\Photo\2018.09.14 Смоленск
# 276 jpg files in subdirectory
# years: 2018 - 2018 ; months: 9 - 9 ; days: 14 - 14
#
# 279
# D:\Photo\2018.09.15-17 Минск
# 385 jpg files in subdirectory
# years: 2018 - 2018 ; months: 9 - 9 ; days: 15 - 17
#
# 280
# D:\Photo\2018.09.17 Мирский замок
# 67 jpg files in subdirectory
# years: 2018 - 2018 ; months: 9 - 9 ; days: 17 - 17
#
# 281
# D:\Photo\2018.09.17 Несвиж
# 100 jpg files in subdirectory
# years: 2018 - 2018 ; months: 9 - 9 ; days: 17 - 17
#
# 282
# D:\Photo\2018.09.27 Вид из окна 14 этажа. Закат
# 7 jpg files in subdirectory
# years: 2018 - 2018 ; months: 9 - 9 ; days: 27 - 27
#
# 283
# D:\Photo\2018.09.29-10.01 Хельсинки + паром на Талинн
# 900 jpg files in subdirectory
# years: 2018 - 2018 ; months: 9 - 10 ; days: 1 - 30
#
# 284
# D:\Photo\2018.10.01 Талинн
# 363 jpg files in subdirectory
# years: 2018 - 2018 ; months: 10 - 10 ; days: 1 - 1
#
# 285
# D:\Photo\2018.10.02-04 Стокгольм
# 1252 jpg files in subdirectory
# years: 2018 - 2018 ; months: 10 - 10 ; days: 2 - 4
#
# 286
# D:\Photo\2018.10.05 Турку
# 5 jpg files in subdirectory
# years: 2018 - 2018 ; months: 10 - 10 ; days: 5 - 5
#
# 287
# D:\Photo\2018.10.10 Осенний вид из окна 14 этажа
# 24 jpg files in subdirectory
# years: 2018 - 2018 ; months: 10 - 10 ; days: 10 - 10
#
# 288
# D:\Photo\2018.10.13 Огромный месяц из окна 14 этажа
# 21 jpg files in subdirectory
# years: 2018 - 2018 ; months: 10 - 10 ; days: 13 - 13
#
# 289
# D:\Photo\2018.10.13 Первая осень деток
# 353 jpg files in subdirectory
# years: 2018 - 2018 ; months: 10 - 10 ; days: 13 - 13
#
# 290
# D:\Photo\2018.10.28 ФОто на Грин карту
# 33 jpg files in subdirectory
# years: 2018 - 2018 ; months: 10 - 10 ; days: 28 - 28
#
# 291
# D:\Photo\2018.11.01-10 Австро-Германия
# 2623 jpg files in subdirectory
# years: 2018 - 2018 ; months: 11 - 11 ; days: 1 - 10
#
# 292
# D:\Photo\2018.11.11-14 Венгрия
# 650 jpg files in subdirectory
# years: 2018 - 2018 ; months: 11 - 11 ; days: 11 - 14
#
# 293
# D:\Photo\2018.11.17 День рождения Лизы и Жени
# 45 jpg files in subdirectory
# years: 2018 - 2018 ; months: 11 - 11 ; days: 17 - 17
#
# 294
# D:\Photo\2018.12.31 Новый год 2019
# 37 jpg files in subdirectory
# years: 2018 - 2018 ; months: 12 - 12 ; days: 31 - 31
#
# 295
# D:\Photo\2019.01.22 Хороший снимок луны из окна 14 этажа
# 13 jpg files in subdirectory
# years: 2019 - 2019 ; months: 1 - 1 ; days: 22 - 22
#
# 296
# D:\Photo\2019.02.02 Детская новогодняя фотосессия
# 317 jpg files in subdirectory
# years: 2019 - 2019 ; months: 2 - 2 ; days: 2 - 2
#
# 297
# D:\Photo\2019.02.13 Зимний вид из окна 14 этажа
# 13 jpg files in subdirectory
# years: 2019 - 2019 ; months: 2 - 2 ; days: 13 - 13
#
# 298
# D:\Photo\2019.02.14 Цветы на День святого Валентина
# 8 jpg files in subdirectory
# years: 2019 - 2019 ; months: 2 - 2 ; days: 15 - 15
#
# 299
# D:\Photo\2019.02.19 Луна с 14 эажа
# 8 jpg files in subdirectory
# years: 2019 - 2019 ; months: 2 - 2 ; days: 19 - 19
#
# 300
# D:\Photo\2019.03 Закаты
# 23 jpg files in subdirectory
# years: 2019 - 2019 ; months: 6 - 7 ; days: 2 - 9
#
# 301
# D:\Photo\2019.03.02 День рождения Платона
# 10 jpg files in subdirectory
# years: 2019 - 2019 ; months: 3 - 3 ; days: 2 - 2
#
# 302
# D:\Photo\2019.03.20 Данина ДР фотосессия
# 27 jpg files in subdirectory
# years: 2019 - 2019 ; months: 3 - 3 ; days: 20 - 20
#
# 303
# D:\Photo\2019.06.10 Даня фото на паспорт
# 5 jpg files in subdirectory
# years: 2019 - 2019 ; months: 6 - 6 ; days: 10 - 10
#
# 304
# D:\Photo\2019.08-12 Наш Лондон
# 1998 jpg files in subdirectory
# years: 2019 - 2019 ; months: 10 - 12 ; days: 1 - 31
#
# 305
# D:\Photo\2019.09.14-15 Выходные у английского моря
# 561 jpg files in subdirectory
# years: 2019 - 2019 ; months: 9 - 9 ; days: 14 - 15
#
# 306
# D:\Photo\2019.10.20 Брайтон
# 366 jpg files in subdirectory
# years: 2019 - 2019 ; months: 10 - 10 ; days: 20 - 20
#
# 307
# D:\Photo\2019.12.20-29 Рождественское Путешествие по Великобритании
# 3066 jpg files in subdirectory
# years: 2019 - 2019 ; months: 12 - 12 ; days: 22 - 29
#
# 308
# D:\Photo\2019.12.29-2020.01.10 Родители в Лондоне
# 445 jpg files in subdirectory
# years: 2019 - 2020 ; months: 1 - 12 ; days: 1 - 31
# Warning!!! Some files with creation time == None in the directory
#
# 309
# D:\Photo\2019.12.31 Новый год в Лондоне с родителями
# 77 jpg files in subdirectory
# years: 2020 - 2020 ; months: 1 - 1 ; days: 1 - 1
#
# 310
# D:\Photo\2020.03 Фотосессия Даня и Лиза в лучших домах Лондона
# 558 jpg files in subdirectory
# years: 2020 - 2020 ; months: 3 - 3 ; days: 10 - 10

# %%
# Check creation times in one of the subfolders:
subdirectory = r'Test\Photoset\2020'
get_creation_times_range(subdirectory)
# Out:
# years: 2020 - 2020 ; months: 6 - 6 ; days: 13 - 13

# %%
file_path = r'Test\Photoset\2018\0.jpeg'
get_creation_time(file_path)
# Out:
# '2018:09:08 00:00:00'

# %% [markdown]
# ### Correct metadata (if needed)

# %% [raw]
# # Change single file creation datetime (if needed)
# file_path_to_change_metadata = r'Test\Photoset\2018\0.jpeg'
# change_jpg_datetime(file_path_to_change_metadata, 2018, 9, 8)

# %%
# Change creation times of all jpg files in a folder to specific date
folder_to_change_metadata = r'D:\Photo\2013.06.15 Свадьба Аллы и Миши'
get_creation_times_range(folder_to_change_metadata)
change_datetime_in_folder(folder_to_change_metadata, 2013, 6, 15)
get_creation_times_range(folder_to_change_metadata)
# Out:
# years: 2013 - 2013 ; months: 6 - 6 ; days: 15 - 16
# Warning!!! Some files with creation time == None in the directory
# ---------------------------------------------------------------------------
# InvalidImageDataError                     Traceback (most recent call last)
# <ipython-input-21-eafb02260f4a> in <module>
#       2 folder_to_change_metadata = r'D:\Photo\2013.06.15 Свадьба Аллы и Миши'
#       3 get_creation_times_range(folder_to_change_metadata)
# ----> 4 change_datetime_in_folder(folder_to_change_metadata, 2013, 6, 15)
#       5 get_creation_times_range(folder_to_change_metadata)
#
# ~\OneDrive - Imperial College London\ML\_Face\utils.py in change_datetime_in_folder(directory, Year, Mo, Da)
#     118     """
#     119     jpg_filenames_list = get_jpg_filenames(directory)
# --> 120     change_jpg_list_datetime(jpg_filenames_list, Year, Mo, Da)
#     121
#     122 def creation_times_range(creation_times_list):
#
# ~\OneDrive - Imperial College London\ML\_Face\utils.py in change_jpg_list_datetime(jpg_filenames_list, year, month, day)
#     103     """
#     104     for filename in jpg_filenames_list:
# --> 105         exif_dict = piexif.load(filename)
#     106         exif_dict['Exif'] = {piexif.ExifIFD.DateTimeOriginal: datetime(year, month, day, 0, 0, 0).strftime("%Y:%m:%d %H:%M:%S")}
#     107         exif_bytes = piexif.dump(exif_dict)
#
# ~\Anaconda3\envs\DL_env\lib\site-packages\piexif\_load.py in load(input_data, key_is_name)
#      26                  "1st":{},
#      27                  "thumbnail":None}
# ---> 28     exifReader = _ExifReader(input_data)
#      29     if exifReader.tiftag is None:
#      30         return exif_dict
#
# ~\Anaconda3\envs\DL_env\lib\site-packages\piexif\_load.py in __init__(self, data)
#     102                     self.tiftag = _webp.get_exif(file_data)
#     103                 else:
# --> 104                     raise InvalidImageDataError("Given file is neither JPEG nor TIFF.")
#     105
#     106     def get_ifd_dict(self, pointer, ifd_name, read_unknown=False):
#
# InvalidImageDataError: Given file is neither JPEG nor TIFF.

# %% [markdown]
# # 1. MTCNN (Multi-Task CNN)
# Multi Task CNN performs multiple tasks simultaneously: face detection and face allignment - i.e. finding face box and landmarks (coordinates of eyes, nose, mouth edges) on the face.
# - Original paper (2016): https://arxiv.org/abs/1604.02878
# - Github repo: https://github.com/ipazc/mtcnn by https://www.linkedin.com/in/ivandepazcenteno/:
# - Description with examples https://machinelearningmastery.com/how-to-perform-face-detection-with-classical-and-deep-learning-methods-in-python-with-keras/

# %%
# Scan a folder with subfolders containing photos and perfrom MTCNN on all photos, save results to a csv file
# Depending on the archive size, scanning photos might take a lot of time.
# The results are saved to the MTCNN_results file for each photo scanned.
# Thus, if interrupted, the results are still saved, and the scan can continued later.
# If new photos are added to the archive this function will do MTCNN only for new photos.
# If one wants a completly new scan with different parameters (min_face_size) new MTCNN_results csv file should be created

# Main archive photo folder with subfolders containing photos
photo_folder = r'Test\Photoset'
# csv file to save scan results
MTCNN_results_file_path = r'Test\MTCNN_results.csv'

# %%
# %%time
# Run MTCNN and save results:
get_mtcnn_results(photo_folder, MTCNN_results_file_path, min_face_size = 100)
# Out:
#   0%|                                                                                           | 0/14 [00:00<?, ?it/s]
# 14 jpg files in directory
# 0 jpg files already scanned before
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [00:26<00:00,  1.92s/it]
# Wall time: 41.9 s

# %% [markdown]
# ## 2. Filter photos

# %%
# Load the saved dataframe with the MTCNN results
df = load_MTCNN_scan_results(MTCNN_results_file_path)
df.tail()
# Out:
# 14 jpg files scanned with MTCNN
# 14 jpg files with detected faces
# 28 total faces detected on all photos
#                           file_path creation_date  \
# 23  Test\Photoset\2020\IMG_3798.JPG    2020-06-13
# 24  Test\Photoset\2020\IMG_3798.JPG    2020-06-13
# 25  Test\Photoset\2020\IMG_3798.JPG    2020-06-13
# 26  Test\Photoset\2020\IMG_3836.JPG    2020-06-13
# 27  Test\Photoset\2020\IMG_3836.JPG    2020-06-13
#
#                                          MTCNN_result
# 23  {'box': [2868, 2381, 148, 165], 'confidence': ...
# 24  {'box': [3530, 1464, 164, 226], 'confidence': ...
# 25  {'box': [3375, 2210, 150, 192], 'confidence': ...
# 26  {'box': [2503, 3312, 124, 138], 'confidence': ...
# 27  {'box': [1601, 3273, 170, 209], 'confidence': ...

# %% [markdown]
# ## MTCNN results need filtering for several reasons:
# E.g: Not a face detected, face size is too small for further processing, photo not in front (person looks to the side), face not in focus, face is inclined too much, grayscale image, etc...
#
# ### Define the filters:
# - **confidence_filter** allows to filter out photos with low confidence. MTCNN provides its confidence in a found face as one of it output results. Low confidence values correspond to either not-a-face (objects resembling face) or occluded faces - it is better to filter them out, e.g. faces with confidence less than 0.99 will be excluded.
#
# - **face_height_filter**. Faces with height less than face_height_filter will be excluded.  Although MTCNN takes min_face_size as an argument some of the found faces are smaller than the min_face_size parameter.
#
# - **nose_shift_filter**. If nose shift is bigger than e.g 15 - face will be excluded. I tried to filter out the photos which are not in front. Nose shift is determined from positions of eyes and nose landmarks and if the nose is strongly shifted relative to center between the eyes the photo is filtered out.
#
# - **eye_line_angle_filter**. If eye_line_angle is more than eye_line_angle_filter - face will be excluded. All photos will be rotated so that the eyeline is horizontal.
#
# - **sharpness_filter**. Assessment of bluriness of an image. Bigger value - lower bluriness. Idea taken from https://www.pyimagesearch.com/2015/09/07/blur-detection-with-opencv/ and modified. I found it emperically that (max-min)**2/var is working better than simple variance as an assessment of bluriness, it is also implemented on a central part of the face around nose (not on the whole face image). If sharpness is less than sharpness_filter face will be excluded

# %%
# Let's define the filters:
confidence_filter = 0.98
face_height_filter = 10
nose_shift_filter = 25
eye_line_angle_filter = 45
sharpness_filter = 20
# grayscale_image_filter is on by default, so no grayscale images will pass through

# And preview the images (one can find appropriate filters depending on the task)
# The landmarks on faces are shown in preview mode and are not saved in the save mode
save_image_folder = False
preview = True

plt.rcParams["figure.figsize"] = (3,3)
image_filter(df[0:100], save_image_folder, preview, confidence_filter, face_height_filter, nose_shift_filter, eye_line_angle_filter, sharpness_filter)
# Out:
# C:\Users\edyshlyu\OneDrive - Imperial College London\ML\_Face\utils.py:422: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['face_file_path'] = np.NaN
# 0it [00:00, ?it/s]
# 0 image from total of 1 scanned images
# Test\Photoset\2008\1.jpg
# angle = -15 ; nose shift = 1 ; sharpness = 528
# 1it [00:00,  3.94it/s]
# 1 image from total of 2 scanned images
# Test\Photoset\2008\1.jpg
# angle = -21 ; nose shift = 7 ; sharpness = 191
# 2it [00:00,  3.88it/s]
# 2 image from total of 4 scanned images
# Test\Photoset\2008\S7300012.JPG
# angle = -11 ; nose shift = 17 ; sharpness = 243
# 4it [00:00,  4.39it/s]
# 3 image from total of 5 scanned images
# Test\Photoset\2008\S7300073.JPG
# angle = -8 ; nose shift = 5 ; sharpness = 94
# 5it [00:01,  3.93it/s]
# 4 image from total of 6 scanned images
# Test\Photoset\2008\S7300639.JPG
# angle = 1 ; nose shift = 12 ; sharpness = 120
# 6it [00:01,  3.74it/s]
# 5 image from total of 7 scanned images
# Test\Photoset\2008\S7300639.JPG
# angle = -5 ; nose shift = 5 ; sharpness = 118
# 7it [00:01,  3.60it/s]
# 6 image from total of 8 scanned images
# Test\Photoset\2018\0.jpeg
# angle = 17 ; nose shift = 25 ; sharpness = 47
# 8it [00:02,  2.62it/s]
# 7 image from total of 9 scanned images
# Test\Photoset\2018\0.jpeg
# angle = 6 ; nose shift = 25 ; sharpness = 53
# 9it [00:03,  2.17it/s]
# 8 image from total of 13 scanned images
# Test\Photoset\2018\x-254.jpg
# angle = 11 ; nose shift = 10 ; sharpness = 47
# 13it [00:03,  2.71it/s]
# 9 image from total of 14 scanned images
# Test\Photoset\2018\x-347.jpg
# angle = -1 ; nose shift = 6 ; sharpness = 52
# 14it [00:04,  2.32it/s]
# 10 image from total of 15 scanned images
# Test\Photoset\2018\x-347.jpg
# angle = -9 ; nose shift = 24 ; sharpness = 57
# 15it [00:04,  2.10it/s]
# 11 image from total of 16 scanned images
# Test\Photoset\2018\x-347.jpg
# angle = -7 ; nose shift = 0 ; sharpness = 58
# 16it [00:05,  1.96it/s]
# 12 image from total of 17 scanned images
# Test\Photoset\2018\x-363.jpg
# angle = -8 ; nose shift = 1 ; sharpness = 82
# 17it [00:06,  1.76it/s]
# 13 image from total of 18 scanned images
# Test\Photoset\2018\x-38.jpg
# angle = 0 ; nose shift = 14 ; sharpness = 39
# 18it [00:06,  1.75it/s]
# 14 image from total of 19 scanned images
# Test\Photoset\2018\x-74.jpg
# angle = 1 ; nose shift = 3 ; sharpness = 39
# 19it [00:07,  1.96it/s]
# 15 image from total of 21 scanned images
# Test\Photoset\2020\IMG_3682.JPG
# angle = -8 ; nose shift = 21 ; sharpness = 263
# 21it [00:07,  2.26it/s]
# 16 image from total of 22 scanned images
# Test\Photoset\2020\IMG_3682.JPG
# angle = 13 ; nose shift = 3 ; sharpness = 252
# 22it [00:08,  2.08it/s]
# 17 image from total of 24 scanned images
# Test\Photoset\2020\IMG_3798.JPG
# angle = -10 ; nose shift = 11 ; sharpness = 155
# 24it [00:08,  2.37it/s]
# 18 image from total of 25 scanned images
# Test\Photoset\2020\IMG_3798.JPG
# angle = 5 ; nose shift = 2 ; sharpness = 136
# 25it [00:09,  2.18it/s]
# 19 image from total of 26 scanned images
# Test\Photoset\2020\IMG_3798.JPG
# angle = -4 ; nose shift = 7 ; sharpness = 149
# 26it [00:09,  2.07it/s]
# 20 image from total of 27 scanned images
# Test\Photoset\2020\IMG_3836.JPG
# angle = -11 ; nose shift = 8 ; sharpness = 106
# 27it [00:10,  1.93it/s]
# 21 image from total of 28 scanned images
# Test\Photoset\2020\IMG_3836.JPG
# angle = -4 ; nose shift = 5 ; sharpness = 83
# 28it [00:11,  2.54it/s]
# Empty DataFrame
# Columns: [file_path, creation_date, MTCNN_result, face_file_path]
# Index: []

# %%
# %%time
# Now that we decided on filter parameters for the task, let's get and save the filtered results:
save_image_folder = r'Test\Cropped_face_images'
preview = False

df_filtered = image_filter(df, save_image_folder, preview, confidence_filter, face_height_filter, nose_shift_filter, eye_line_angle_filter, sharpness_filter)

#file_path_filtered_results = r'output\MTCNN_min_face_200_filtered.csv'
file_path_filtered_results = r'Test\MTCNN_results_filtered.csv'

print('Number of faces before filtering:', len(df), 'Number of faces after filtering:', len(df_filtered))
df_filtered.to_csv(file_path_filtered_results,index=False)
# Out:
# 0it [00:00, ?it/s]C:\Users\edyshlyu\Anaconda3\envs\DL_env\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# 28it [00:07,  3.67it/s]
# Number of faces before filtering: 28 Number of faces after filtering: 22
# Wall time: 7.64 s

# %%
#df_filtered = pd.read_csv(r'output\MTCNN_min_face_200_filtered.csv')
df_filtered = pd.read_csv(file_path_filtered_results)
print(len(df_filtered))
df_filtered.head()
# Out:
# 22
#                          file_path creation_date  \
# 0         Test\Photoset\2008\1.jpg    2008-06-01
# 1         Test\Photoset\2008\1.jpg    2008-06-01
# 2         Test\Photoset\2008\1.jpg    2008-06-01
# 3  Test\Photoset\2008\S7300012.JPG    2008-08-02
# 4  Test\Photoset\2008\S7300073.JPG    2008-08-02
#
#                                         MTCNN_result  \
# 0  {'box': [434, 568, 400, 490], 'confidence': 0....
# 1  {'box': [1228, 247, 473, 555], 'confidence': 0...
# 2  {'box': [219, 1059, 850, 1066], 'confidence': ...
# 3  {'box': [1025, 919, 167, 235], 'confidence': 0...
# 4  {'box': [1142, 932, 167, 215], 'confidence': 0...
#
#                    face_file_path
# 0  Test\Cropped_face_images\0.jpg
# 1  Test\Cropped_face_images\1.jpg
# 2  Test\Cropped_face_images\2.jpg
# 3  Test\Cropped_face_images\3.jpg
# 4  Test\Cropped_face_images\4.jpg

# %% [markdown]
# ## 3. FaceNet Embeddings

# %%
# load the pretrained facenet model
# The model is taking 160X160 colored figure as input 
# And outputs 128 value vector of embedding generated from this figure
model = load_model(r'facenet_keras_pretrained/model/facenet_keras.h5')
print('model_input:', model.inputs)
print('model_output:', model.outputs)
#model.summary()
# Out:
# model_input: [<tf.Tensor 'input_1_7:0' shape=(?, 160, 160, 3) dtype=float32>]
# model_output: [<tf.Tensor 'Bottleneck_BatchNorm_6/cond/Merge:0' shape=(?, 128) dtype=float32>]
# C:\Users\edyshlyu\Anaconda3\envs\DL_env\lib\site-packages\keras\engine\saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %% [raw]
# # Get single embedding
# image_path = r'Test\Cropped_face_images\0.jpg'
# emb = get_facenet_embedding(image_path, model)
# print(emb.shape)

# %%
# %%time
# Get embeddings for all face images
embeddings = []
for file_path in tqdm(df_filtered['face_file_path']):
    emb = get_facenet_embedding(file_path, model)
    embeddings.append(emb)
embeddings = np.array(embeddings)
#print(embeddings.shape)

# Save embeddings to the file
embeddings_file_path = r'Test\embeddings'
np.save(embeddings_file_path, embeddings)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 22/22 [00:08<00:00,  2.58it/s]
# Wall time: 8.54 s

# %% [markdown]
# ## t-SNE

# %%
# Load filetered results
df_filtered = pd.read_csv(file_path_filtered_results)

# load the embeddings
X = np.load('Test\embeddings.npy')

# %%
# Calculate t-SNE
X_tsne = TSNE(perplexity=2, learning_rate = 1000, n_iter=1000, random_state=0).fit_transform(X)

x = X_tsne[:,0]
y = X_tsne[:,1]
paths =  df_filtered.face_file_path
creation_dates = df_filtered.creation_date


# The idea on how to plot faces is taken from https://stackoverflow.com/questions/22566284/matplotlib-how-to-plot-images-instead-of-points
def getImage(path, size):
    image = plt.imread(path)
    image = resize_image(image, size)
    return OffsetImage(image)

plt.rcParams["figure.figsize"] = (20,20)
# This part is plotting faces
fig, ax = plt.subplots()
ax.scatter(x, y)
for x0, y0, path in zip(x, y, paths):
    ab = AnnotationBbox(getImage(path, (50,50)), (x0, y0), frameon=False)
    ax.add_artist(ab)

# This part is plotting colors
# Creation date is shown with colors on the plot below
# Spectral(rainbow) palette is used with older photos shown in red and recent in blue
sns.scatterplot(x=x, y=y, hue = creation_date, s=7000, palette=sns.color_palette('Spectral',len(set(creation_dates))))
#plt.legend([],[], frameon=False) # hide the legend if it too long

# Set figure background
sns.set_style("whitegrid", {'axes.grid' : False,'axes.facecolor': 'white'})
plt.show()

# %% [markdown]
# As we see t-SNE separated these photos to groups using face embeddings generated by FaceNet. t-SNE is not ideal (one photo of my daughter mixed with my son's phots on this figure for example), and the result depends on the hyperparameters of the t-SNE algorithm. It also initialize randomly, so changing random_state brings different results. The output becomes more robust and accurate if more photos is used as is shown below for 1700 facial images from my archive. On this figure I can clearly members of our family and friends nicely separated to groups.<img src="Test/all.png">
# # Do try it for your photo archive!
